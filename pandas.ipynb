# %% [markdown]
# ### Load 'titanic_train.csv' CSV file and save last 5 rows in Excel format

# %%
import pandas as pd
df = pd.read_csv("files/titanic_train.csv")

#df1 = df[-5:]

#df1.to_csv("files/titanic_train_lastfive.csv")

df.tail(5).to_excel("files/titanic_train_lastfive.xlsx")

# %% [markdown]
# ### Load Excel file from previous exercise and save it again with only first four columns

# %%
df = pd.read_excel("files/titanic_train_lastfive.xlsx")
df.iloc[:, :4].to_excel("files/titanic_train_lastfive_4.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     351         try:
# --> 352             import xlrd
#     353         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-3af0d432fdd3> in <module>
# ----> 1 df = pd.read_excel("files/titanic_train_lastfive.xlsx")
#       2 df.iloc[:, :4].to_excel("files/titanic_train_lastfive_4.xlsx")
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\excel.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, **kwds)
#     305
#     306     if not isinstance(io, ExcelFile):
# --> 307         io = ExcelFile(io, engine=engine)
#     308
#     309     return io.parse(
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     352             import xlrd
#     353         except ImportError:
# --> 354             raise ImportError(err_msg)
#     355         else:
#     356             ver = tuple(map(int, xlrd.__VERSION__.split(".")[:2]))
#
# ImportError: Install xlrd >= 0.9.0 for Excel support

# %% [markdown]
# ### Test how loc and iloc works (be creative :) )

# %%
df = pd.read_csv("files/titanic_train.csv")
df.head
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %% [markdown]
# ### Załaduj plik csv z `titanic_train.csv` z folderu `files_pandas_21_01_2017`
#
# #### Sprawdź pierwsze wiersze
#
# #### Policz wystąpienia wartości zmiennej survived
#
# #### Sprawdź typy danych

# %% [markdown]
# # Wróćmy do wykładu - Zmiana typów danych w czasie odczytu

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Load 'titanic_train.csv' file, with category type for all columns that are compatible with this type.

# %% [markdown]
# ### Fill NaN values in Age column with mean value of this column.

# %% [markdown]
# ### Fill NaN values in Embarked with most common location.

# %% [markdown]
# ### Create 3 Series with different indexes that overlap a bit (i.e. 1-10, 5-15, 10-20). Create DataFrame from them and see what happens.

# %% [markdown]
# ### Display passengers with Age above 50

# %%
df = pd.read_csv("files/titanic_train.csv")
#df.loc[df["Age"] > 50]
df[df.Age > 50]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# 94            95         0       3
# 96            97         0       1
# 116          117         0       3
# 124          125         0       1
# 150          151         0       2
# 152          153         0       3
# 155          156         0       1
# 170          171         0       1
# 174          175         0       1
# 195          196         1       1
# 222          223         0       3
# 232          233         0       2
# 249          250         0       2
# 252          253         0       1
# 262          263         0       1
# 268          269         1       1
# 275          276         1       1
# 280          281         0       3
# 317          318         0       2
# 326          327         0       3
# 366          367         1       1
# 406          407         0       3
# 438          439         0       1
# 449          450         1       1
# 456          457         0       1
# ..           ...       ...     ...
# 493          494         0       1
# 496          497         1       1
# 513          514         1       1
# 545          546         0       1
# 555          556         0       1
# 570          571         1       2
# 571          572         1       1
# 582          583         0       2
# 587          588         1       1
# 591          592         1       1
# 625          626         0       1
# 626          627         0       2
# 630          631         1       1
# 631          632         0       3
# 647          648         1       1
# 659          660         0       1
# 672          673         0       2
# 684          685         0       2
# 694          695         0       1
# 695          696         0       2
# 714          715         0       2
# 745          746         0       1
# 765          766         1       1
# 772          773         0       2
# 774          775         1       2
# 820          821         1       1
# 829          830         1       1
# 851          852         0       3
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
#
# 438      4        19950  263.0000  C23 C25 C27        S
# 449      0       113786   30.5000         C104        S
# 456      0        13509   26.5500          E38        S
# ..     ...          ...       ...          ...      ...
# 493      0     PC 17609   49.5042          NaN        C
# 496      0        36947   78.2667          D20        C
# 513      0     PC 17603   59.4000          NaN        C
# 545      0          693   26.0000          NaN        S
# 555      0       113807   26.5500          NaN        S
# 570      0  S.W./PP 752   10.5000          NaN        S
# 571      0        11769   51.4792         C101        S
# 582      0        28403   26.0000          NaN        S
# 587      1        13567   79.2000          B41        C
# 591      0        36947   78.2667          D20        C
# 625      0        36963   32.3208          D50        S
# 626      0       219533   12.3500          NaN        Q
# 630      0        27042   30.0000          A23        S
# 631      0       347743    7.0542          NaN        S
# 647      0        13213   35.5000          A26        C
# 659      2        35273  113.2750          D48        C
# 672      0   C.A. 24580   10.5000          NaN        S
# 684      1        29750   39.0000          NaN        S
# 694      0       113800   26.5500          NaN        S
# 695      0       248731   13.5000          NaN        S
# 714      0       250647   13.0000          NaN        S
# 745      1    WE/P 5735   71.0000          B22        S
# 765      0        13502   77.9583          D11        S
# 772      0  S.O./P.P. 3   10.5000          E77        S
# 774      3        29105   23.0000          NaN        S
# 820      1        12749   93.5000          B69        S
# 829      0       113572   80.0000          B28      NaN
# 851      0       347060    7.7750          NaN        S
# 857      0       113055   26.5500          E17        S
# 879      1        11767   83.1583          C50        C
#
# [64 rows x 12 columns]

# %% [markdown]
# ### Display passengers that Embarked at location S and are female

# %%
df = pd.read_csv("files/titanic_train.csv")
#df.loc[df[[["Sex"] == "female"] & df[["Embarked"] == "S"]]]
df[(df.Embarked == "S") & (df.Sex == "female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 24            25         0       3
# 25            26         1       3
# 38            39         0       3
# 40            41         0       3
# 41            42         0       2
# 49            50         0       3
# 53            54         1       2
# 56            57         1       2
# 58            59         1       2
# 66            67         1       2
# 68            69         1       3
# 71            72         0       3
# 79            80         1       3
# 84            85         1       2
# 85            86         1       3
# 88            89         1       1
# 98            99         1       2
# 100          101         0       3
# 106          107         1       3
# 113          114         0       3
# 119          120         0       3
# 123          124         1       2
# ..           ...       ...     ...
# 765          766         1       1
# 772          773         0       2
# 774          775         1       2
# 777          778         1       3
# 779          780         1       1
# 781          782         1       1
# 786          787         1       3
# 792          793         0       3
# 796          797         1       1
# 797          798         1       3
# 799          800         0       3
# 801          802         1       2
# 807          808         0       3
# 809          810         1       1
# 813          814         0       3
# 816          817         0       3
# 820          821         1       1
# 823          824         1       3
# 853          854         1       1
# 854          855         0       2
# 855          856         1       3
# 856          857         1       1
# 862          863         1       1
# 863          864         0       3
# 865          866         1       2
# 871          872         1       1
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 24                       Palsson, Miss. Torborg Danira  female   8.0      3
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 38                  Vander Planke, Miss. Augusta Maria  female  18.0      2
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 49       Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 53   Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# 56                                   Rugg, Miss. Emily  female  21.0      0
# 58                        West, Miss. Constance Mirium  female   5.0      1
# 66                        Nye, Mrs. (Elizabeth Ramell)  female  29.0      0
# 68                     Andersson, Miss. Erna Alexandra  female  17.0      4
# 71                          Goodwin, Miss. Lillian Amy  female  16.0      5
# 79                            Dowdell, Miss. Elizabeth  female  30.0      0
# 84                                 Ilett, Miss. Bertha  female  17.0      0
# 85   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 88                          Fortune, Miss. Mabel Helen  female  23.0      3
# 98                Doling, Mrs. John T (Ada Julia Bone)  female  34.0      0
# 100                            Petranec, Miss. Matilda  female  28.0      0
# 106                   Salkjelsvik, Miss. Anna Kristine  female  21.0      0
# 113                            Jussila, Miss. Katriina  female  20.0      1
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 123                                Webber, Miss. Susan  female  32.5      0
# ..                                                 ...     ...   ...    ...
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1
# 772                                  Mack, Mrs. (Mary)  female  57.0      0
# 774              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0      1
# 777                      Emanuel, Miss. Virginia Ethel  female   5.0      0
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 786                          Sjoblom, Miss. Anna Sofia  female  18.0      0
# 792                            Sage, Miss. Stella Anna  female   NaN      8
# 796                        Leader, Dr. Alice (Farnham)  female  49.0      0
# 797                                   Osman, Mrs. Mara  female  31.0      0
# 799  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...  female  30.0      1
# 801        Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1
# 807                    Pettersson, Miss. Ellen Natalia  female  18.0      0
# 809     Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.0      1
# 813                 Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 816                       Heininen, Miss. Wendla Maria  female  23.0      0
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 823                                 Moor, Mrs. (Beila)  female  27.0      0
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 854      Carter, Mrs. Ernest Courtenay (Lilian Hughes)  female  44.0      1
# 855                         Aks, Mrs. Sam (Leah Rosen)  female  18.0      0
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 863                  Sage, Miss. Dorothy Edith "Dolly"  female   NaN      8
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket      Fare        Cabin Embarked
# 2        0  STON/O2. 3101282    7.9250          NaN        S
# 3        0            113803   53.1000         C123        S
# 8        2            347742   11.1333          NaN        S
# 10       1           PP 9549   16.7000           G6        S
# 11       0            113783   26.5500         C103        S
# 14       0            350406    7.8542          NaN        S
# 15       0            248706   16.0000          NaN        S
# 18       0            345763   18.0000          NaN        S
# 24       1            349909   21.0750          NaN        S
# 25       5            347077   31.3875          NaN        S
# 38       0            345764   18.0000          NaN        S
# 40       0              7546    9.4750          NaN        S
# 41       0             11668   21.0000          NaN        S
# 49       0            349237   17.8000          NaN        S
# 53       0              2926   26.0000          NaN        S
# 56       0        C.A. 31026   10.5000          NaN        S
# 58       2        C.A. 34651   27.7500          NaN        S
# 66       0        C.A. 29395   10.5000          F33        S
# 68       2           3101281    7.9250          NaN        S
# 71       2           CA 2144   46.9000          NaN        S
# 79       0            364516   12.4750          NaN        S
# 84       0        SO/C 14885   10.5000          NaN        S
# 85       0           3101278   15.8500          NaN        S
# 88       2             19950  263.0000  C23 C25 C27        S
# 98       1            231919   23.0000          NaN        S
# 100      0            349245    7.8958          NaN        S
# 106      0            343120    7.6500          NaN        S
# 113      0              4136    9.8250          NaN        S
# 119      2            347082   31.2750          NaN        S
# 123      0             27267   13.0000         E101        S
# ..     ...               ...       ...          ...      ...
# 765      0             13502   77.9583          D11        S
# 772      0       S.O./P.P. 3   10.5000          E77        S
# 774      3             29105   23.0000          NaN        S
# 777      0            364516   12.4750          NaN        S
# 779      1             24160  211.3375           B3        S
# 781      0             17474   57.0000          B20        S
# 786      0           3101265    7.4958          NaN        S
# 792      2          CA. 2343   69.5500          NaN        S
# 796      0             17465   25.9292          D17        S
# 797      0            349244    8.6833          NaN        S
# 799      1            345773   24.1500          NaN        S
# 801      1        C.A. 31921   26.2500          NaN        S
# 807      0            347087    7.7750          NaN        S
# 809      0            113806   53.1000           E8        S
# 813      2            347082   31.2750          NaN        S
# 816      0  STON/O2. 3101290    7.9250          NaN        S
# 820      1             12749   93.5000          B69        S
# 823      1            392096   12.4750         E121        S
# 853      1          PC 17592   39.4000          D28        S
# 854      0            244252   26.0000          NaN        S
# 855      1            392091    9.3500          NaN        S
# 856      1             36928  164.8667          NaN        S
# 862      0             17466   25.9292          D17        S
# 863      2          CA. 2343   69.5500          NaN        S
# 865      0            236852   13.0000          NaN        S
# 871      1             11751   52.5542          D35        S
# 880      1            230433   26.0000          NaN        S
# 882      0              7552   10.5167          NaN        S
# 887      0            112053   30.0000          B42        S
# 888      2        W./C. 6607   23.4500          NaN        S
#
# [203 rows x 12 columns]

# %% [markdown]
# ### Display passengers that paid for ticket more than 50 and are not in first class

# %% [markdown]
# ### Display all passengers with Names that contain 'Johnson' (it's a surname)

# %%
df[df.Name.str.contains("Johnson")]
# Out:
#      PassengerId  Survived  Pclass  \
# 8              9         1       3
# 172          173         1       3
# 302          303         0       3
# 597          598         0       3
# 719          720         0       3
# 869          870         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 172                       Johnson, Miss. Eleanor Ileen  female   1.0      1
# 302                    Johnson, Mr. William Cahoone Jr    male  19.0      0
# 597                                Johnson, Mr. Alfred    male  49.0      0
# 719                       Johnson, Mr. Malkolm Joackim    male  33.0      0
# 869                    Johnson, Master. Harold Theodor    male   4.0      1
#
#      Parch  Ticket     Fare Cabin Embarked
# 8        2  347742  11.1333   NaN        S
# 172      1  347742  11.1333   NaN        S
# 302      0    LINE   0.0000   NaN        S
# 597      0    LINE   0.0000   NaN        S
# 719      0  347062   7.7750   NaN        S
# 869      1  347742  11.1333   NaN        S

# %%
df.Sex.value_counts() #liczy ile powtorzen ma dana wartość występująca w kolumnie
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.groupby("Sex").agg({"Age":["mean"], "Survived":["sum"]}) #liczy średnią wieku dla kobiet i mężczyzn
# Out:
#               Age
#              mean
# Sex
# female  27.915709
# male    30.726645

# %% [markdown]
# # Dodatkowe ćwiczenia
#
# Korzystając z pliku `matches.csv` zawierającego dane o rozgrywkach piłkarskich:
#
# 1. Znajdź wszystkie mecze pomiędzy dwoma wybranymi drużynami w latach 2010-2015.\
# 2. Znajdź 10 meczów z największą różnicą bramek.
# 3. Policz liczbę zdobytych i straconych bramek na sezon dla wybranej drużyny. Narysuj wykres obrazujący uzyskane wyniki.
# 4. Policz średnią liczbę bramek przypadającą na jeden mecz w każdej lidze. Narysuj wykres obrazujący uzyskane wyniki.

# %%
data = pd.read_csv("files/matches.csv", parse_dates=['date'])
data.head()
# Out:
#    country                  league          home_team          away_team  \
# 0  Belgium  Belgium Jupiler League           KRC Genk       Beerschot AC
# 1  Belgium  Belgium Jupiler League   SV Zulte-Waregem   Sporting Lokeren
# 2  Belgium  Belgium Jupiler League  KSV Cercle Brugge     RSC Anderlecht
# 3  Belgium  Belgium Jupiler League           KAA Gent          RAEC Mons
# 4  Belgium  Belgium Jupiler League      FCV Dender EH  Standard de Liège
#
#         date     season  home_team_goal  away_team_goal
# 0 2008-08-17  2008/2009               1               1
# 1 2008-08-16  2008/2009               0               0
# 2 2008-08-16  2008/2009               0               3
# 3 2008-08-17  2008/2009               5               0
# 4 2008-08-16  2008/2009               1               3

# %%
data[
    ((data.home_team == "Legia Warszawa") | (data.away_team == "Legia Warszawa")) &
    ((data.home_team == "Lech Poznań") | (data.away_team == "Lech Poznań")) &
    (data.date.dt.year.isin([2010, 2011, 2012, 2013, 2014, 2015]))
]
# Out:
#       country              league       home_team       away_team       date  \
# 16088  Poland  Poland Ekstraklasa     Lech Poznań  Legia Warszawa 2010-04-03
# 16315  Poland  Poland Ekstraklasa     Lech Poznań  Legia Warszawa 2011-04-16
# 16419  Poland  Poland Ekstraklasa  Legia Warszawa     Lech Poznań 2010-09-24
# 16468  Poland  Poland Ekstraklasa     Lech Poznań  Legia Warszawa 2011-10-30
# 16596  Poland  Poland Ekstraklasa  Legia Warszawa     Lech Poznań 2012-04-21
# 16706  Poland  Poland Ekstraklasa     Lech Poznań  Legia Warszawa 2012-11-18
# 16836  Poland  Poland Ekstraklasa  Legia Warszawa     Lech Poznań 2013-05-18
# 16960  Poland  Poland Ekstraklasa     Lech Poznań  Legia Warszawa 2013-10-27
# 17088  Poland  Poland Ekstraklasa  Legia Warszawa     Lech Poznań 2014-03-29
# 17172  Poland  Poland Ekstraklasa  Legia Warszawa     Lech Poznań 2014-09-27
# 17300  Poland  Poland Ekstraklasa     Lech Poznań  Legia Warszawa 2015-03-22
# 17440  Poland  Poland Ekstraklasa  Legia Warszawa     Lech Poznań 2015-10-25
#
#           season  home_team_goal  away_team_goal
# 16088  2009/2010               1               0
# 16315  2010/2011               1               0
# 16419  2010/2011               2               1
# 16468  2011/2012               0               0
# 16596  2011/2012               0               1
# 16706  2012/2013               1               3
# 16836  2012/2013               1               0
# 16960  2013/2014               1               1
# 17088  2013/2014               1               0
# 17172  2014/2015               2               2
# 17300  2014/2015               2               1
# 17440  2015/2016               0               1

# %%
data['goal_diff'] = (data.home_team_goal - data.away_team_goal).abs()
data.sort_values('goal_diff', ascending = False).head(10)
# Out:
#            country                   league         home_team  \
# 13898  Netherlands   Netherlands Eredivisie               PSV
# 7660        France           France Ligue 1      ES Troyes AC
# 20161     Scotland  Scotland Premier League            Celtic
# 9761       Germany    Germany 1. Bundesliga  FC Bayern Munich
# 22984        Spain          Spain LIGA BBVA      FC Barcelona
# 22310        Spain          Spain LIGA BBVA        UD Almería
# 2420       England   England Premier League           Chelsea
# 24015        Spain          Spain LIGA BBVA    Real Madrid CF
# 24247        Spain          Spain LIGA BBVA    Real Madrid CF
# 4375       England   England Premier League       Southampton
#
#                  away_team       date     season  home_team_goal  \
# 13898            Feyenoord 2010-10-24  2010/2011              10
# 7660   Paris Saint-Germain 2016-03-13  2015/2016               0
# 20161             Aberdeen 2010-11-06  2010/2011               9
# 9761          Hamburger SV 2015-02-14  2014/2015               8
# 22984           CA Osasuna 2011-09-17  2011/2012               8
# 22310         FC Barcelona 2010-11-20  2010/2011               0
# 2420        Wigan Athletic 2010-05-09  2009/2010               8
# 24015           Granada CF 2015-04-05  2014/2015               9
# 24247       Rayo Vallecano 2015-12-20  2015/2016              10
# 4375            Sunderland 2014-10-18  2014/2015               8
#
#        away_team_goal  goal_diff
# 13898               0         10
# 7660                9          9
# 20161               0          9
# 9761                0          8
# 22984               0          8
# 22310               8          8
# 2420                0          8
# 24015               1          8
# 24247               2          8
# 4375                0          8

# %%
team = "Celtic"
team_matches = data[(data.home_team == team) | (data.away_team == team)]
team_matches.reset_index(inplace=True)
team_matches
# Out:
#      index   country                   league                     home_team  \
# 0    19697  Scotland  Scotland Premier League                        Celtic
# 1    19699  Scotland  Scotland Premier League                        Celtic
# 2    19707  Scotland  Scotland Premier League           Heart of Midlothian
# 3    19711  Scotland  Scotland Premier League                        Celtic
# 4    19717  Scotland  Scotland Premier League                        Celtic
# 5    19728  Scotland  Scotland Premier League        Hamilton Academical FC
# 6    19734  Scotland  Scotland Premier League                    St. Mirren
# 7    19735  Scotland  Scotland Premier League                        Celtic
# 8    19743  Scotland  Scotland Premier League                     Hibernian
# 9    19747  Scotland  Scotland Premier League                        Celtic
# 10   19757  Scotland  Scotland Premier League                       Falkirk
# 11   19760  Scotland  Scotland Premier League                 Dundee United
# 12   19765  Scotland  Scotland Premier League                       Rangers
# 13   19771  Scotland  Scotland Premier League                        Celtic
# 14   19781  Scotland  Scotland Premier League                      Aberdeen
# 15   19783  Scotland  Scotland Premier League                        Celtic
# 16   19791  Scotland  Scotland Premier League  Inverness Caledonian Thistle
# 17   19795  Scotland  Scotland Premier League                        Celtic
# 18   19802  Scotland  Scotland Premier League                    Motherwell
# 19   19807  Scotland  Scotland Premier League                        Celtic
# 20   19815  Scotland  Scotland Premier League                    Kilmarnock
# 21   19819  Scotland  Scotland Premier League                        Celtic
# 22   19825  Scotland  Scotland Premier League                        Celtic
# 23   19832  Scotland  Scotland Premier League                 Dundee United
# 24   19837  Scotland  Scotland Premier League                        Celtic
# 25   19844  Scotland  Scotland Premier League           Heart of Midlothian
# 26   19849  Scotland  Scotland Premier League                        Celtic
# 27   19855  Scotland  Scotland Premier League                      Aberdeen
# 28   19862  Scotland  Scotland Premier League                       Rangers
# 29   19867  Scotland  Scotland Premier League                        Celtic
# ..     ...       ...                      ...                           ...
# 274  21337  Scotland  Scotland Premier League                        Celtic
# 275  21348  Scotland  Scotland Premier League              St. Johnstone FC
# 276  21349  Scotland  Scotland Premier League                        Celtic
# 277  21358  Scotland  Scotland Premier League          Partick Thistle F.C.
# 278  21364  Scotland  Scotland Premier League           Heart of Midlothian
# 279  21368  Scotland  Scotland Premier League                     Dundee FC
# 280  21373  Scotland  Scotland Premier League                        Celtic
# 281  21379  Scotland  Scotland Premier League                 Dundee United
# 282  21389  Scotland  Scotland Premier League                        Celtic
# 283  21391  Scotland  Scotland Premier League                      Aberdeen
# 284  21397  Scotland  Scotland Premier League                        Celtic
# 285  21403  Scotland  Scotland Premier League                        Celtic
# 286  21411  Scotland  Scotland Premier League        Hamilton Academical FC
# 287  21415  Scotland  Scotland Premier League                        Celtic
# 288  21425  Scotland  Scotland Premier League                    Kilmarnock
# 289  21431  Scotland  Scotland Premier League          Partick Thistle F.C.
# 290  21436  Scotland  Scotland Premier League                    Kilmarnock
# 291  21440  Scotland  Scotland Premier League                        Celtic
# 292  21449  Scotland  Scotland Premier League                    Motherwell
# 293  21455  Scotland  Scotland Premier League                        Celtic
# 294  21457  Scotland  Scotland Premier League           Heart of Midlothian
# 295  21468  Scotland  Scotland Premier League                        Celtic
# 296  21470  Scotland  Scotland Premier League              St. Johnstone FC
# 297  21479  Scotland  Scotland Premier League                        Celtic
# 298  21481  Scotland  Scotland Premier League                        Celtic
# 299  21488  Scotland  Scotland Premier League                 Dundee United
# 300  21493  Scotland  Scotland Premier League                        Celtic
# 301  21499  Scotland  Scotland Premier League                      Aberdeen
# 302  21505  Scotland  Scotland Premier League                        Celtic
# 303  21511  Scotland  Scotland Premier League                        Celtic
#
#                         away_team       date     season  home_team_goal  \
# 0                      St. Mirren 2008-08-10  2008/2009               1
# 1                       Hibernian 2008-10-25  2008/2009               4
# 2                          Celtic 2008-11-02  2008/2009               0
# 3                      Motherwell 2008-11-08  2008/2009               2
# 4                      Kilmarnock 2008-11-12  2008/2009               3
# 5                          Celtic 2008-11-16  2008/2009               1
# 6                          Celtic 2008-11-22  2008/2009               1
# 7    Inverness Caledonian Thistle 2008-11-29  2008/2009               1
# 8                          Celtic 2008-12-07  2008/2009               2
# 9             Heart of Midlothian 2008-12-13  2008/2009               1
# 10                         Celtic 2008-12-21  2008/2009               0
# 11                         Celtic 2008-08-17  2008/2009               1
# 21                0          4
# 22                0          3
# 23                2          0
# 24                0          4
# 25                1          0
# 26                0          2
# 27                3          2
# 28                0          1
# 29                1          1
# ..              ...        ...
# 274               1          7
# 275               3          3
# 276               2          1
# 277               2          2
# 278               2          0
# 279               0          0
# 280               0          1
# 281               4          3
# 282               1          2
# 283               1          1
# 284               0          2
# 285               0          3
# 286               1          0
# 287               0          0
# 288               2          0
# 289               2          1
# 290               1          1
# 291               1          2
# 292               2          1
# 293               1          0
# 294               3          2
# 295               2          1
# 296               1          1
# 297               0          7
# 298               2          2
# 299               3          2
# 300               1          2
# 301               1          1
# 302               0          6
# 303               0          0
#
# [304 rows x 10 columns]

# %%
def team_goals(x):
    team = "Celtic"
    if x.home_team == team:
        return x.home_team_goal
    elif x.away_team == team:
        return x.away_team_goal
    
    
#def opponents_goals(x):
 #   if x.home_team == team:
  #      return x.home_team_goal
   # elif x.away_team == team:
    #    return x.away_team_goal

# %%
#team_matches["team_goals"] = team_matches.apply(lambda x: x.home_team_goal if x.home_team == team else x.away_team_goal, axis 1)
team_matches["team_goals"] = team_matches.apply["team_goals"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-099aa51956e5> in <module>
#       1 #team_matches["team_goals"] = team_matches.apply(lambda x: x.home_team_goal if x.home_team == team else x.away_team_goal, axis 1)
# ----> 2 team_matches["team_goals"] = team_matches.apply["team_goals"]
#
# TypeError: 'method' object is not subscriptable

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.country.value_counts()
# Out:
# France         3040
# England        3040
# Spain          3040
# Italy          3017
# Germany        2448
# Netherlands    2448
# Portugal       2052
# Poland         1920
# Scotland       1824
# Belgium        1728
# Switzerland    1422
# Name: country, dtype: int64

# %%
goals_per_country = data.groupby("country").agg({'goal_sum':sum})
# Out:
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\groupby\groupby.py:4656: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'goal_sum'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-51bdd9ed5b62> in <module>
# ----> 1 goals_per_country = data.groupby("country").agg({'goal_sum':sum})
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4654         axis=''))
#    4655     def aggregate(self, arg, *args, **kwargs):
# -> 4656         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4657
#    4658     agg = aggregate
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4085
#    4086         _level = kwargs.pop('_level', None)
# -> 4087         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    4088         if how is None:
#    4089             return result
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     488
#     489                 try:
# --> 490                     result = _agg(arg, _agg_1dim)
#     491                 except SpecificationError:
#     492
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     439                 result = compat.OrderedDict()
#     440                 for fname, agg_how in compat.iteritems(arg):
# --> 441                     result[fname] = func(fname, agg_how)
#     442                 return result
#     443
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     418                 aggregate a 1-dim with how
#     419                 """
# --> 420                 colg = self._gotitem(name, ndim=1, subset=subset)
#     421                 if colg.ndim != 1:
#     422                     raise SpecificationError("nested dictionary is ambiguous "
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\groupby\groupby.py in _gotitem(self, key, ndim, subset)
#    4681         elif ndim == 1:
#    4682             if subset is None:
# -> 4683                 subset = self.obj[key]
#    4684             return SeriesGroupBy(subset, selection=key,
#    4685                                  grouper=self.grouper)
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# c:\users\kurs\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'goal_sum'
